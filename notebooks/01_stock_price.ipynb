# %%
import yfinance as yf

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data=yf.download("AAPL", start="2020-01-01", end="2025-09-26")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.loc("2025-09-26")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.loc("2025-09-26")
#
# NameError: name 'df' is not defined

# %%
data.loc["2025-09-25"]
# Out:
# Price   Ticker
# Close   AAPL      2.568700e+02
# High    AAPL      2.571700e+02
# Low     AAPL      2.517100e+02
# Open    AAPL      2.532100e+02
# Volume  AAPL      5.506130e+07
# Name: 2025-09-25 00:00:00, dtype: float64

# %%
print(data.loc["2025-09-25"])
# Out:
# Price   Ticker
# Close   AAPL      2.568700e+02
# High    AAPL      2.571700e+02
# Low     AAPL      2.517100e+02
# Open    AAPL      2.532100e+02
# Volume  AAPL      5.506130e+07
# Name: 2025-09-25 00:00:00, dtype: float64

# %%
data["MA20"] = data["Adj Close"].rolling(window=20).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/quant/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Adj Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ...

# %%
print(data.columns)
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
print(data.columns)
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
data = data.droplevel('Ticker', axis=1)

# %%
data["MA20"] = data["Adj Close"].rolling(window=20).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/quant/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Adj Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ...

# %%
print(data.columns)
# Out:
# Index(['Close', 'High', 'Low', 'Open', 'Volume'], dtype='object', name='Price')

# %%
data["MA20"] = data["Close"].rolling(window=20).mean()

# %%
data['MA50'] = data[close].rolling(50).mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data['MA50'] = data[close].rolling(50).mean()
#
# NameError: name 'close' is not defined

# %%
data['MA50'] = data[Close].rolling(50).mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data['MA50'] = data[Close].rolling(50).mean()
#
# NameError: name 'Close' is not defined

# %%
data['MA50'] = data[“Close”].rolling(50).mean()
# Out:
#   Cell In[24], line 1
#     data['MA50'] = data[“Close”].rolling(50).mean()
#                         ^
# SyntaxError: invalid character '“' (U+201C)

# %%
data["MA50"] = data["Close"].rolling(50).mean()

# %%
import matplotlib.pyplot as plt

# %%
df["Return"] = df["Close"].pct_change()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df["Return"] = df["Close"].pct_change()
#
# NameError: name 'df' is not defined

# %%
data["Return"] = data["Close"].pct_change()
print(data.head())
# Out:
# Price           Close       High        Low       Open     Volume  MA20  MA50  \
# Date
# 2020-01-02  72.538536  72.598914  71.292326  71.545912  135480400   NaN   NaN
# 2020-01-03  71.833290  72.594055  71.608685  71.765667  146322800   NaN   NaN
# 2020-01-06  72.405678  72.444321  70.703012  70.954188  118387200   NaN   NaN
# 2020-01-07  72.065163  72.671356  71.845385  72.415353  108872000   NaN   NaN
# 2020-01-08  73.224411  73.526303  71.768086  71.768086  132079200   NaN   NaN
#
# Price         Return
# Date
# 2020-01-02       NaN
# 2020-01-03 -0.009722
# 2020-01-06  0.007968
# 2020-01-07 -0.004703
# 2020-01-08  0.016086

# %%
print(data.head(25))
# Out:
# Price           Close       High        Low       Open     Volume       MA20  \
# Date
# 2020-01-02  72.538536  72.598914  71.292326  71.545912  135480400        NaN
# 2020-01-03  71.833290  72.594055  71.608685  71.765667  146322800        NaN
# 2020-01-06  72.405678  72.444321  70.703012  70.954188  118387200        NaN
# 2020-01-07  72.065163  72.671356  71.845385  72.415353  108872000        NaN
# 2020-01-08  73.224411  73.526303  71.768086  71.768086  132079200        NaN
# 2020-01-09  74.779747  74.972955  73.951358  74.202527  170108400        NaN
# 2020-01-10  74.948822  75.513970  74.446478  75.014035  140644800        NaN
# 2020-01-13  76.550064  76.576634  75.146872  75.265219  121532000        NaN
# 2020-01-14  75.516365  76.697368  75.393198  76.487253  161954400        NaN
# 2020-01-15  75.192726  76.197422  74.760415  75.315900  121923600        NaN
# 2020-01-16  76.134644  76.245745  75.373878  75.736148  108829200        NaN
# ...

# %%
plt.figure(figsize=(12,6))

# %%
plt.plot(data["Close"], label="AAPL Close", linewidth=1.5)

# %%
plt.plot(data["MA20"], label="20-day MA", linestyle="--")
plt.plot(data["MA50"], label="50-day MA", linestyle="--")
plt.title("Apple Stock Price with Moving Averages")
# Out:
# Text(0.5, 1.0, 'Apple Stock Price with Moving Averages')

# %%
plt.figure(figsize=(12,6))
plt.plot(data["Adj Close"], label="AAPL Adj Close", linewidth=1.5)
plt.plot(data["MA20"], label="20-day MA", linestyle="--")
plt.plot(data["MA50"], label="50-day MA", linestyle="--")
plt.title("Apple Stock Price with Moving Averages")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/quant/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Adj Close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 2
# ...

# %%
plt.figure(figsize=(12,6))
plt.plot(data["Close"], label="AAPL Close", linewidth=1.5)
plt.plot(data["MA20"], label="20-day MA", linestyle="--")
plt.plot(data["MA50"], label="50-day MA", linestyle="--")
plt.title("Apple Stock Price with Moving Averages")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
